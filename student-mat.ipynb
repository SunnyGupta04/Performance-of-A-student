# %%
# # Importing warning 

import warnings

warnings.filterwarnings('ignore')

# %%
# Importing pandas ,numpy,seaborn,matplotlib library.

import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
# Reding the student data 

df=pd.read_csv("H:\Profesional books\Data Science Course\Dcoder\Data Sets\Test\student-mat.csv")

# %%
df.head(5)
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %% [markdown]
# Data Cleaning

# %%
# getting information about data sets

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %%
# converting the time travel to date and time from int64

df["traveltime"]=pd.to_datetime(df["traveltime"])

# %%
# converting the study time to date and time from int64

df["studytime"]=pd.to_datetime(df["studytime"])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    datetime64[ns]
#  13  studytime   395 non-null    datetime64[ns]
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
# ...

# %%
df['school'].value_counts()
# Out:
# GP    349
# MS     46
# Name: school, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# F    208
# M    187
# Name: sex, dtype: int64

# %%
df['age'].value_counts()
# Out:
# 16    104
# 17     98
# 18     82
# 15     82
# 19     24
# 20      3
# 22      1
# 21      1
# Name: age, dtype: int64

# %%
sns.distplot(df['age'])
plt.show()

# %%
df['address'].value_counts()
# Out:
# U    307
# R     88
# Name: address, dtype: int64

# %%
df['famsize'].value_counts()
# Out:
# GT3    281
# LE3    114
# Name: famsize, dtype: int64

# %%
df['Pstatus'].value_counts()
# Out:
# T    354
# A     41
# Name: Pstatus, dtype: int64

# %%
df['Medu'].value_counts()
# Out:
# 4    131
# 2    103
# 3     99
# 1     59
# 0      3
# Name: Medu, dtype: int64

# %%
df['Fedu'].value_counts()
# Out:
# 2    115
# 3    100
# 4     96
# 1     82
# 0      2
# Name: Fedu, dtype: int64

# %%
df['Mjob'].value_counts()
# Out:
# other       141
# services    103
# at_home      59
# teacher      58
# health       34
# Name: Mjob, dtype: int64

# %%
df['Fjob'].value_counts()
# Out:
# other       217
# services    111
# teacher      29
# at_home      20
# health       18
# Name: Fjob, dtype: int64

# %%
df['famrel'].value_counts()
# Out:
# 4    195
# 5    106
# 3     68
# 2     18
# 1      8
# Name: famrel, dtype: int64

# %%
df['freetime'].value_counts()
# Out:
# 3    157
# 4    115
# 2     64
# 5     40
# 1     19
# Name: freetime, dtype: int64

# %%
df['goout'].value_counts()
# Out:
# 3    130
# 2    103
# 4     86
# 5     53
# 1     23
# Name: goout, dtype: int64

# %%
df['Dalc'].value_counts()
# Out:
# 1    276
# 2     75
# 3     26
# 5      9
# 4      9
# Name: Dalc, dtype: int64

# %%
df['Walc'].value_counts()
# Out:
# 1    151
# 2     85
# 3     80
# 4     51
# 5     28
# Name: Walc, dtype: int64

# %%
df['health'].value_counts()
# Out:
# 5    146
# 3     91
# 4     66
# 1     47
# 2     45
# Name: health, dtype: int64

# %%
df['absences'].value_counts()
# Out:
# 0     115
# 2      65
# 4      53
# 6      31
# 8      22
# 10     17
# 14     12
# 12     12
# 3       8
# 7       7
# 16      7
# 18      5
# 5       5
# 20      4
# 22      3
# 13      3
# 1       3
# 9       3
# 11      3
# 15      3
# 23      1
# 24      1
# 21      1
# 25      1
# 56      1
# 26      1
# 28      1
# 30      1
# 17      1
# 38      1
# 40      1
# 54      1
# 19      1
# 75      1
# Name: absences, dtype: int64

# %%
df['G1'].value_counts()
# Out:
# 10    51
# 8     41
# 11    39
# 7     37
# 12    35
# 13    33
# 9     31
# 14    30
# 15    24
# 6     24
# 16    22
# 17     8
# 18     8
# 5      7
# 19     3
# 4      1
# 3      1
# Name: G1, dtype: int64

# %%
df['G2'].value_counts()
# Out:
# 9     50
# 10    46
# 12    41
# 13    37
# 11    35
# 15    34
# 8     32
# 14    23
# 7     21
# 5     15
# 6     14
# 0     13
# 16    13
# 18    12
# 17     5
# 19     3
# 4      1
# Name: G2, dtype: int64

# %%
df['G3'].value_counts()
# Out:
# 10    56
# 11    47
# 0     38
# 15    33
# 8     32
# 13    31
# 12    31
# 9     28
# 14    27
# 16    16
# 6     15
# 18    12
# 7      9
# 5      7
# 17     6
# 19     5
# 4      1
# 20     1
# Name: G3, dtype: int64

# %%
# fetching the numeric data 

df_numeric = df.select_dtypes(include=['int64', 'float64'])
df_numeric.head()
# Out:
#    age  Medu  Fedu  failures  famrel  freetime  goout  Dalc  Walc  health  \
# 0   18     4     4         0       4         3      4     1     1       3
# 1   17     1     1         0       5         3      3     1     1       3
# 2   15     1     1         3       4         3      2     2     3       3
# 3   15     4     2         0       3         2      2     1     1       5
# 4   16     3     3         0       4         3      2     1     2       5
#
#    absences  G1  G2  G3
# 0         6   5   6   6
# 1         4   5   5   6
# 2        10   7   8  10
# 3         2  15  14  15
# 4         4   6  10  10

# %%
# creating pair plot 

plt.figure(figsize = (100,100))
sns.pairplot(df_numeric)
plt.show()

# %% [markdown]
# As there are lot of columns- so it is not possible to  make out really much from above graph. Let us check the correlation.

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(), annot=True, cmap='YlGnBu')
plt.show()

# %% [markdown]
# Inference :
#
# 1. As we can see age is highly correlated with,failures,famrel,freetime,goout,Dalc,Walc,absences,
#
# 2. Age is is negatively correlated with G1,G2,G3,Fedu,Medu,helth

# %%
# comparing with school other Group

# %%
df[['school','G3']].groupby(df['school'],as_index=True).std()
# Out:
#               G3
# school
# GP      4.625397
# MS      4.237229

# %%
sns.boxplot(x="school",y="G3", data=df)
plt.show()

# %%
df[['school','G2']].groupby(df['school'],as_index=True).std()
# Out:
#               G2
# school
# GP      3.808434
# MS      3.377175

# %%
sns.boxplot(x="school",y="G2", data=df)
plt.show()

# %%
df[['school','G1']].groupby(df['school'],as_index=True).std()
# Out:
#               G1
# school
# GP      3.319109
# MS      3.347001

# %%
sns.boxplot(x="school",y="G1", data=df)
plt.show()

# %% [markdown]
# Inference:
#
# As we can see that mean grade of G3 is higher then G1 and G2

# %% [markdown]
# comparing with sex with other groups

# %%
df[['sex','G1']].groupby(df['sex'],as_index=True).std()
# Out:
#            G1
# sex
# F    3.232530
# M    3.392839

# %%
sns.boxplot(x="sex",y="G1", data=df)
plt.show()

# %%
df[['sex','G2']].groupby(df['sex'],as_index=True).std()
# Out:
#            G2
# sex
# F    3.641851
# M    3.868088

# %%
sns.boxplot(x="sex",y="G2", data=df)
plt.show()

# %%
df[['sex','G3']].groupby(df['sex'],as_index=True).std()
# Out:
#            G3
# sex
# F    4.622338
# M    4.495297

# %%
sns.boxplot(x="sex",y="G3", data=df)
plt.show()

# %% [markdown]
# Inference:
#
# As we can see that mean grade of Male  is higher then Female in all the group

# %%
sns.boxplot(x="Medu",y="G1", data=df)
plt.show()

# %%
sns.boxplot(x="Medu",y="G2", data=df)
plt.show()

# %%
sns.boxplot(x="Medu",y="G3", data=df)
plt.show()

# %% [markdown]
# Inference:
#
# G1 have good mean as compare to G2 ,G3

# %%
sns.boxplot(x="Fedu",y="G1", data=df)
plt.show()

# %%
sns.boxplot(x="Fedu",y="G2", data=df)
plt.show()

# %%
sns.boxplot(x="Fedu",y="G3", data=df)
plt.show()

# %% [markdown]
# G1 has lower range of mean if we compare to G2 and G3

# %%
sns.boxplot(x="failures",y="G1", data=df)
plt.show()

# %%
sns.boxplot(x="failures",y="G2", data=df)
plt.show()

# %%
sns.boxplot(x="failures",y="G3", data=df)
plt.show()

# %% [markdown]
# Inference:
#
# G3 have hi range of faliure as compare to G1 and G2

# %%
sns.boxplot(x="famrel",y="G1", data=df)
plt.show()

# %%
sns.boxplot(x="famrel",y="G2", data=df)
plt.show()

# %%
sns.boxplot(x="famrel",y="G3", data=df)
plt.show()

# %% [markdown]
# Inference:
#
# G1 having more range of famrel then G2 and G3

# %%
sns.boxplot(x="freetime",y="G1", data=df)
plt.show()

# %%
sns.boxplot(x="freetime",y="G2", data=df)
plt.show()

# %%
sns.boxplot(x="freetime",y="G3", data=df)
plt.show()

# %% [markdown]
# Inference:
#
# G1 getting less freetime as compare to G2 and G3

# %%
sns.boxplot(x="goout",y="G1", data=df)
plt.show()

# %%
sns.boxplot(x="goout",y="G2", data=df)
plt.show()

# %%
sns.boxplot(x="goout",y="G3", data=df)
plt.show()

# %% [markdown]
# Inference:
#
# G2 getting  more goout time as compare to G3 but less with G1

# %%
sns.boxplot(x="Dalc",y="G1", data=df)
plt.show()

# %%
sns.boxplot(x="Dalc",y="G2", data=df)
plt.show()

# %%
sns.boxplot(x="Dalc",y="G3", data=df)
plt.show()

# %% [markdown]
# Inference:
#
# G1 having poor performance in dalc 4 as compare to G2,G3 Dalc 4

# %%
sns.boxplot(x="Walc",y="G1", data=df)
plt.show()

# %%
sns.boxplot(x="Walc",y="G2", data=df)
plt.show()

# %%
sns.boxplot(x="Walc",y="G3", data=df)
plt.show()

# %% [markdown]
# Inference:
#
#     G2 having poor performance in walc 5 as compare with G1 and G2

# %%
sns.boxplot(x="health",y="G1", data=df)
plt.show()

# %%
sns.boxplot(x="health",y="G2", data=df)
plt.show()

# %%
sns.boxplot(x="health",y="G3", data=df)
plt.show()

# %% [markdown]
# Inference:
#
# G3 having good health as compare to G1 and G2 in health 5

# %%
sns.boxplot(x="absences",y="G1", data=df)
plt.show()

# %%
sns.boxplot(x="absences",y="G2", data=df)
plt.show()

# %%
sns.boxplot(x="absences",y="G3", data=df)
plt.show()

# %% [markdown]
# Inference:
#
# G3 having more range of absence as compare to G1and G2

# %%
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime goout Dalc  Walc health absences  G1  G2  G3
# 0      4        3     4    1     1      3        6   5   6   6
# 1      5        3     3    1     1      3        4   5   5   6
# 2      4        3     2    2     3      3       10   7   8  10
# 3      3        2     2    1     1      5        2  15  14  15
# 4      4        3     2    1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
plt.hist(df['sex'])
plt.title('Comparision with Gender Absences ')
plt.xlabel('Number of Day Absent')
plt.ylabel('Student Total Number ')
plt.yticks([0, 100, 200, 300, 400])
plt.show()

# %% [markdown]
# Inference:
#
# Female student are getting little bit more absent as compare to Male student

# %%
df.columns
# Out:
# Index(['school', 'sex', 'age', 'address', 'famsize', 'Pstatus', 'Medu', 'Fedu',
#        'Mjob', 'Fjob', 'reason', 'guardian', 'traveltime', 'studytime',
#        'failures', 'schoolsup', 'famsup', 'paid', 'activities', 'nursery',
#        'higher', 'internet', 'romantic', 'famrel', 'freetime', 'goout', 'Dalc',
#        'Walc', 'health', 'absences', 'G1', 'G2', 'G3'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    datetime64[ns]
#  13  studytime   395 non-null    datetime64[ns]
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
# ...

# %%
df = df.select_dtypes(include=['int64', 'float64'])
df.head()
# Out:
#    age  Medu  Fedu  failures  famrel  freetime  goout  Dalc  Walc  health  \
# 0   18     4     4         0       4         3      4     1     1       3
# 1   17     1     1         0       5         3      3     1     1       3
# 2   15     1     1         3       4         3      2     2     3       3
# 3   15     4     2         0       3         2      2     1     1       5
# 4   16     3     3         0       4         3      2     1     2       5
#
#    absences  G1  G2  G3
# 0         6   5   6   6
# 1         4   5   5   6
# 2        10   7   8  10
# 3         2  15  14  15
# 4         4   6  10  10

# %%
df.isna().sum()
# Out:
# age         0
# Medu        0
# Fedu        0
# failures    0
# famrel      0
# freetime    0
# goout       0
# Dalc        0
# Walc        0
# health      0
# absences    0
# G1          0
# G2          0
# G3          0
# dtype: int64
